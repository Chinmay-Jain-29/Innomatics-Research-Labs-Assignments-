# %% [markdown]
# # Problem 1: Smart Light Controller

# %%
class smart_light_controller:
    def light_controller(light_type,status):
        print(f"{light_type} is {status}")

light_type= input("Enter the type of light")
status = input("enter Status ")
sm = smart_light_controller
sm.light_controller(light_type,status)
# Out:
# Enter the type of light bedroom light
# enter Status  on
# bedroom light is on

# %% [markdown]
# # Problem 2: Employee ID Card System

# %%
class employee:
    def employee_id_detail(name , emp_id, dept):
        print(f"\nEMPLOYEE ID CARD: \nEMPLOYEE NAME :{name} \n EMPLOYEE ID : {emp_id} \n DEPARTMENT OF EMPLOYEE : {dept}")

name = input("enter name of employee")
emp_id = input("enter emplloyee id")
dept = input("enter the department of employee")

emp = employee
emp.employee_id_detail(name , emp_id, dept)
# Out:
# enter name of employee chnmay
# enter emplloyee id e121
# enter the department of employee cse
# EMPLOYEE ID CARD
# EMPLOYEE NAME :chnmay
#  EMPLOYEE ID : e121
#  DEPARTMENT OF EMPLOYEE : cse

# %% [markdown]
# # Problem 3: Mobile Contact Record

# %%
class contact:
    def save_contact_details (contact_name,  contact_number):
        print(f"\n CONTACT SAVED \n name: {contact_name} \n number: {contact_number}")

contact_name  = input("ENTER CONTACT NAME TO BE SAVE ")
contact_number = int(input("ENTER CONTACT NUMBER TO BE SAVE "))
c = contact
c.save_contact_details(contact_name , contact_number)
# Out:
# ENTER CONTACT NAME TO BE SAVE  chinmahy
# ENTER CONTACT NUMBER TO BE SAVE  8698314051
#  CONTACT SAVED
#  name: chinmahy
#  number: 8698314051

# %% [markdown]
# # Problem 4: Product Price Tag Generator

# %%
class product:
    def product_detail(product_name , price):
        print(f"\n Product: {product_name} \n Price: {price}")
product_name = input("ENTER THE PEODUCT NAME ")
price = int(input("ENTER THE PRODUCT PRICE"))
p = product
p.product_detail(product_name,price)
# Out:
# ENTER THE PEODUCT NAME  headphones
# ENTER THE PRODUCT PRICE 2500
#  Product: headphones
#  Price: 2500

# %% [markdown]
# # Problem 5: Movie Rating Display System

# %%
class movie:
    def movie_rating(movie_name , movie_rating):
        print(f"\n MOVIE NAME : {movie_name} \n MOVIE RATING {movie_rating}")
name = input("ENTER MOVIE NAME")
rating= float(input("ENTER MOVIE RATING"))

m = movie
m.movie_rating(name, rating)
# Out:
# ENTER MOVIE NAME dsb
# ENTER MOVIE RATING 2.5
#  MOVIE NAME : dsb
#  MOVIE RATING 2.5

# %% [markdown]
# # Problem 6: Delivery Address Manager

# %%
class address:
    def delivery_address(name , delivery_addres):
        print(f"\n\nDELIVERY DETAILS \n\n NAME: {name} \n ADDRESS: {delivery_address}")

name = input("ENTER NAME ")
delivery_address = input("ENTER ADDRESS")
a = address
a.delivery_address(name,delivery_address)
# Out:
# ENTER NAME  sdvb
# ENTER ADDRESS sdvb
# DELIVERY DETAILS
#
#  NAME: sdvb
#  ADDRESS: sdvb
